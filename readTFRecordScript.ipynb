# %%
import tensorflow as tf
import os

# %%
os.chdir('/Users/anviol/Desktop/train_test/')

# %%
# The MARCO data set contains 462,804 scored images from five source institutions:
# 0 - Collaborative Crystallisation Centre
# 1 - GlaxoSmithKline
# 2 - Hauptman-Woodward Medical Research Institute
# 3 - Merck & Co.
# 4 - Bristol-Myers Squibb

# Images Labels:
# 0 - Clear
# 1 - Crystals
# 2 - Other
# 3 - Precipitate

# TFRecord Features:
# image/height:        integer, image height in pixels
# image/width:         integer, image width in pixels
# image/colorspace:    string, specifying the colorspace, always 'RGB'
# image/channels:      integer, specifying the number of channels, always 3
# image/class/label:   integer, specifying the index in a normalized classification layer
# image/class/raw:     integer, specifying the index in the raw (original) classification layer
# image/class/source:  integer, specifying the index of the source (creator of the image)
# image/class/text:    string, specifying the human-readable version of the normalized label
# image/format:        string, specifying the format, always 'JPEG'
# image/filename:      string containing the basename of the image file
# image/id:            integer, specifying the unique id for the image
# image/encoded:       string, containing JPEG encoded image in RGB colorspace

# %%
# https://medium.com/mostly-ai/tensorflow-records-what-they-are-and-how-to-use-them-c46bc4bbb564

# Read and print data:
sess = tf.InteractiveSession()

# Read TFRecord file
reader = tf.TFRecordReader()
filename_queue = tf.train.string_input_producer(['marcoTrainData00001.tfrecord'])
_, serialized_example = reader.read(filename_queue)

# Define features
read_features = {
    'image/height': tf.FixedLenFeature([], dtype=tf.int64),
    'image/width': tf.FixedLenFeature([], dtype=tf.int64),
    'image/colorspace': tf.FixedLenFeature([], dtype=tf.string),
    'image/class/label': tf.FixedLenFeature([], dtype=tf.int64),
    'image/class/raw': tf.FixedLenFeature([], dtype=tf.int64),
    'image/class/source': tf.FixedLenFeature([], dtype=tf.int64),
    'image/class/text': tf.FixedLenFeature([], dtype=tf.string),
    'image/format': tf.FixedLenFeature([], dtype=tf.string),
    'image/filename': tf.FixedLenFeature([], dtype=tf.string),
    'image/id': tf.FixedLenFeature([], dtype=tf.int64),
    'image/encoded': tf.FixedLenFeature([], dtype=tf.string)
}

# Extract features from serialized data
read_data = tf.parse_single_example(serialized=serialized_example,
                                    features=read_features)

# Many tf.train functions use tf.train.QueueRunner,
# so we need to start it before we read
tf.train.start_queue_runners(sess)

# Print features
for name, tensor in read_data.items():
    print('{}: {}'.format(name, tensor.eval()))
# Out:
# image/class/label: 0
# image/class/raw: 14
# image/class/source: 2
# image/class/text: b'Clear'
# image/colorspace: b'RGB'
# image/encoded: b'\xff\xd8\xff\xdb\x00\x84\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x03\xc0\x05\x00\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x01\xa2\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xbc\xed\xc78`j\x07\xef\xd3\xeb\xc0\xcf\xe9R?Q\xd8\xe0\xe7\xf0?J\x84\x9e;\x0f|\xfd}\xeb\xe9\xb9O\x9cD\x12\x11\xc8 d\x8f\xef\x0f\xf0\xaa\xf2\x1f\x98\x8c/\x07\xd79\xeb\xe9V\x1c\x80H\x04\xf1\xd3\x07\x1f\xd6\xab\xbf\r\xff\x00\xd7\xff\x00\xeb\xd2h\xa4@\xf8\x03 \xe2\xab\xb9^yC\xd7\x9c\x8c\x1a\x9d\xc0\xf7\xaa\xec\xa0\xfa\x13Sb\xd3!b9\xc9\xcf\xa5F\xcaA9\xc9\xc7L\xd4\x8eB\xb0>\xa6\xa1b\x0e\x06@\xe9\xfd)Y\x16\x98\xc7\xc0\'=\xfd\xaa&\xce\x08*rzqN\'oC\x8e\xf5\x0b\x10Nx9\xf6\xa5b\x90\xd6V\x1c\x859\xfat\xa689<`\xfd(e\x04\xf2\x06\rF\xc3\x81\x91\xd3\xa6i4P\x10rI\x18\xfc3Q\x9c\x81\x9c\x1e\x9d\xc5#\x00F\x08\x1d98\xa6\x91\x81\xc0\xa9h\xa4+\x02\t\xca\xe2\xa2<\xf6\xa7\x15\x1c\x1cw\xa6\x9f\xbapA\x06\xa5\xa2\x90\xd6\xce\xe2FO\xe9Lc\x81\x9fZ\x1b\x03\x90\x00\xfc*\x17`\x01\xe9\xcde"\xd0;s\xd4\xe3\xb9\x03\xadW\x91\x8fe\xfc\xe9\xee\xe3\x19$}j\x9c\xae\t\'\x03\x8ek\x9el\xda\x08\x1d\xfa\x85?\xd75\x01c\x8c\x1e>\xa6\x91\x9b\x04\xf7\xcf\xb5DXb\xb9\xa5#x\xa1\xccs\xc0\xc6O|\xe2\x99\x91\x8e\xa3\xafPi\xbd@\xcd.9\xac\xdb-\n1\x8eH\xe4z\xf4\xa5\xc8\xe3$d\xfa\x9cR|\xab\xcfzL\xe5\xb2h\x1d\xc7eO$\xfe]\xa9\xb9\xf5 Pp\x0er)1\x93\x9e\x01\xa0.<\x10NF?\nA\xc9\xed\xf9\xd2\x0c\xe3\x81\x8f\xafjA\x8c\xf4\xa4\x17\x1d\x8e\x01\xc8<\xf5\xcd\x03\x1e\xbf\x95&\x06p:\x9a_\xba9\xa0.\x18\x03\x1f\xa6i3\xee8\xf7\xa4&\x8e\xfc\x9a\x02\xe2\xee\xe3\xee\xf1\xeb\x9e\x94g\xa7\x7fZ8\xc7\'\x8aO\xe4\x07\xe5@j\x19\xc7$c\xf1\xa38=h\xc1\xeb\x83K\x8c\x11\xc5\x02\x1b\x93\x9a3\xfe4\xb4\x9cP\x01\x93\xd6\x8eh\xff\x00&\x93\xbd1\x06\xef|\x8a_\xc7\xff\x00\xafE\x1d\xa8\x00\xc8\xcfA\xd3\xaezQ\x90\t8\xfdh\xeb\xebFx\xa2\xc3\xb8p\x08\xc79\xa3\xf0\xc7>\xb4`\x9e):\xf3\xd6\x80\xb8\xec\xe4\xf4\x02\x93>\xe0~=i;\x7fZ\\`b\x80\xbb\x17\x8e\xbf\xa5\x1c\x7fxc\xebH)8\xcf4\n\xe3\xb1\xcf \x0c\xf7\xcd\x1cc\x07\xa5 \xc8\x1d:\xd2\xe7\xf4\xa0w\x14t\xe4\x8c\x9e\xf9\xa0rs\x91\xc57\xd7\x9a9\xcd1\\p\xc0\xc7+\xf4-J\x07\xa9R{\xfc\xc2\x99\x83\xd0w\xa7\x05\x04\xfe\x15Iy\x05\xc7\x85\x18\xfb\xe9\xff\x00}\x0f\xf1\xa7\x05S\x8c\xc9\x1f\xe2\xc3\x9f\xd6\x98\x17?\xd6\xa5D\'\xb1\xfa\n\xd1E\x92\xd8\xf5D\xff\x00\x9e\xb1\x8f\xf8\x1a\xf1\xfa\xd4\xaa\x88\x00\xfd\xe2u\xec\xc0\xd2ElX\xd5\xe8lX\xe0\x80\xdf\x857\x14L\xa7b\xa8Q\x91\x80I\xec1\xd6\x97cc;_\x1e\xcakMl\xf6\x8c`\x8f\xc7\xa5#\x10\x87\x96\xfdjlG9\x9d\xb0\x93\x80\xacH>\x86\x8f-\x8f@\xd9\xf7^\x95q\xee\x14\ ...
# image/filename: b'folderID647_plateID2647_batchID13388_wellNum72_profileID1_d2_r213829_ef.jpg'
# image/format: b'JPEG'
# image/height: 960
# image/id: 163507
# image/width: 632

# %%
for name, tensor in read_data.items():
    print('{}: {}'.format(name, tensor.eval()))
# Out:
# image/class/label: 3
# image/class/raw: 13
# image/class/source: 3
# image/class/text: b'Precipitate'
# image/colorspace: b'RGB'
# image/filename: b'folderID242_plateID3242_batchID19196_wellNum13_profileID1_d2_r282524_ef.jpg'
# image/format: b'JPEG'
# image/height: 960
# image/id: 208789
# image/width: 1280

# %%
### SAVE ENCODING TO THEN CONVERT BYTEARRAY TO IMAGE
